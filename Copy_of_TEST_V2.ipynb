# %% [markdown]
# <a href="https://colab.research.google.com/github/noragriffith/WBtest/blob/main/Copy_of_TEST_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data from Github repository
url = 'https://raw.githubusercontent.com/noragriffith/WBtest/main/Test_Names.csv?token=AL2ZFH6HUAZGZVKT27TA2PDBRMYSU'
comm_trans_df = pd.read_csv(url)
comm_trans_df
# Out:
#                                     domestic  transaction_id
# 0                 A Class Trading Pvt., Ltd.               1
# 1                     A K Y Lanka Pvt., Ltd.               2
# 2       A R Freight Care Services Pvt., Ltd.               3
# 3       Ace International Express Pvt., Ltd.               4
# 4                   Aero Dynamics (Pvt) Ltd.               5
# ...                                      ...             ...
# 106521                 Usui Lanka (Pvt) Ltd.          106522
# 106522               Variosystems Pvt., Ltd.          106523
# 106523                  Wayamba Natural Peat          106524
# 106524       Wichy Plantation Co. (Pvt) Ltd.          106525
# 106525             Workwear Lanka (Pvt) Ltd.          106526
#
# [106526 rows x 2 columns]

# %%
# Check dataframe information
comm_trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106526 entries, 0 to 106525
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   domestic        105890 non-null  object
#  1   transaction_id  106526 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB

# %%
# Rename 'domestic' column name with a more meaningful name 'firm_name'
comm_trans_df.rename(columns={'domestic': 'firm_name'}, inplace=True)
comm_trans_df
# Out:
#                                    firm_name  transaction_id
# 0                 A Class Trading Pvt., Ltd.               1
# 1                     A K Y Lanka Pvt., Ltd.               2
# 2       A R Freight Care Services Pvt., Ltd.               3
# 3       Ace International Express Pvt., Ltd.               4
# 4                   Aero Dynamics (Pvt) Ltd.               5
# ...                                      ...             ...
# 106521                 Usui Lanka (Pvt) Ltd.          106522
# 106522               Variosystems Pvt., Ltd.          106523
# 106523                  Wayamba Natural Peat          106524
# 106524       Wichy Plantation Co. (Pvt) Ltd.          106525
# 106525             Workwear Lanka (Pvt) Ltd.          106526
#
# [106526 rows x 2 columns]

# %% [markdown]
# # Analyzing null cases
# - **firm_name** is not available for 0.6% of the records. Upon analysis, I decided to remove those records as it did not give any significant insight to the data.

# %%
# Checking null cases
comm_trans_df.isnull().sum()/len(comm_trans_df)*100
# Out:
# firm_name         0.597037
# transaction_id    0.000000
# dtype: float64

# %%
# Records with missing firm_name values
comm_trans_df_null = comm_trans_df[comm_trans_df['firm_name'].isnull()==True]
comm_trans_df_null
# Out:
#        firm_name  transaction_id
# 294          NaN             295
# 3217         NaN            3218
# 8785         NaN            8786
# 9819         NaN            9820
# 10036        NaN           10037
# ...          ...             ...
# 104321       NaN          104322
# 105100       NaN          105101
# 105462       NaN          105463
# 105463       NaN          105464
# 105464       NaN          105465
#
# [636 rows x 2 columns]

# %%
# Records with missing firm_name dropped from the dataframe
#comm_trans_df_null.to_csv('comm_trans_df_null.csv')
#comm_trans_df_null.to_csv("https://github.com/noragriffith/WBtest/comm_trans_df_null.csv")

# %%
# Cleaning records with null values
comm_trans_df = comm_trans_df.dropna()
comm_trans_df.isnull().sum()
# Out:
# firm_name         0
# transaction_id    0
# dtype: int64

# %% [markdown]
# # Data normalization
# - **firm_name** ..............

# %%
# Performs data normalization on a series
def clean_companies(series):
  return series.str.lower().str.replace(r"[^a-z0-9\s]", '').str.replace(r"\b(plc|pivt|pvt|ltd|lt|co|sa)\b",'').str.strip()

# %%
clean_companies(comm_trans_df['firm_name'])
# Out:
# 0                   a class trading
# 1                       a k y lanka
# 2         a r freight care services
# 3         ace international express
# 4                     aero dynamics
#                     ...
# 106521                   usui lanka
# 106522                 variosystems
# 106523         wayamba natural peat
# 106524             wichy plantation
# 106525               workwear lanka
# Name: firm_name, Length: 105890, dtype: object

# %%
# Performs data normalization on firm_name column and add a new column with those clean names
comm_trans_df['firm_name_clean']=clean_companies(comm_trans_df['firm_name'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
comm_trans_df
# Out:
#                                    firm_name  ...            firm_name_clean
# 0                 A Class Trading Pvt., Ltd.  ...            a class trading
# 1                     A K Y Lanka Pvt., Ltd.  ...                a k y lanka
# 2       A R Freight Care Services Pvt., Ltd.  ...  a r freight care services
# 3       Ace International Express Pvt., Ltd.  ...  ace international express
# 4                   Aero Dynamics (Pvt) Ltd.  ...              aero dynamics
# ...                                      ...  ...                        ...
# 106521                 Usui Lanka (Pvt) Ltd.  ...                 usui lanka
# 106522               Variosystems Pvt., Ltd.  ...               variosystems
# 106523                  Wayamba Natural Peat  ...       wayamba natural peat
# 106524       Wichy Plantation Co. (Pvt) Ltd.  ...           wichy plantation
# 106525             Workwear Lanka (Pvt) Ltd.  ...             workwear lanka
#
# [105890 rows x 3 columns]

# %%
grouped_comm_trans_df = comm_trans_df.groupby('firm_name_clean').count()
print(grouped_comm_trans_df)
# Out:
#                             firm_name  transaction_id
# firm_name_clean
#                                     3               3
# 1 billabong place burleigh          1               1
# 1138 colonial drive                 1               1
# 18398 calzedonia shanghai           1               1
# 1f block a emerald gardens          1               1
# ...                               ...             ...
# zpmc lanka                          4               4
# zubair gems                        31              31
# zubair makeen sons                  4               4
# zumbach electronic ag               1               1
# zumoonz gems                        1               1
#
# [14234 rows x 2 columns]

# %%
# create a list of unique names
names = comm_trans_df['firm_name_clean'].unique().tolist()
names
# Out:
# ['a class trading',
#  'a k y lanka',
#  'a r freight care services',
#  'ace international express',
#  'aero dynamics',
#  'akbar bros',
#  'aldora exporters',
#  'alpex marine',
#  'amagi exp',
#  'ansell lanka',
#  'antron express',
#  'ap lanka',
#  'aqua packaging',
#  'aramex lanka',
#  'arrow sea food',
#  'associated speciality rubbers',
#  'atheeb exp',
#  'beyond exp',
#  'bio grow lanka',
#  'borneo exotics',
#  'brandix apparel',
#  'britannia garment packaging p l',
#  'c w mackie',
#  'c r exp',
#  'capitol overseas',
#  'central rubber',
#  'ceylon fresh seafood',
#  'ceylon natural exp',
#  'ceylon paper pottery',
#  'ceylon pest control',
#  'ceylon tea services',
#  'ceymac rubber',
#  'chiefway lanka',
#  'coats thread exp',
#  'coco land lanka',
#  'colombo dockyard',
#  'commercial exp',
#  'consolidated business systems',
#  'csk exp',
#  'd h l keels',
#  'dasa trade center',
#  'decor foliage rathnasiriya meegahamula',
#  'delta gems',
#  'dero exp international',
#  'development interplan ceylon',
#  'diamond cutters',
#  'dilarshad enterprise',
#  'dilcoir mills',
#  'divine worldwide',
#  'dkw aqua international',
#  'dracina plant nursery',
#  'e v r exp',
#  'eam maliban textiles',
#  'earthscape',
#  'eastern allied agencies',
#  'elastomeric engineering',
#  'emar pharma',
#  'emjay international m m center',
#  'eva lanka',
#  'exp global distribution center',
#  'expolanka freight',
#  'fairmount apparels',
#  'fascination exp',
#  'for personal effect exporters',
#  'foundation garments',
#  'frontier holdings',
#  'future world lanka',
#  'garment services meegoda',
#  'ghim li lanka',
#  'gislaved gummi lanka',
#  'global rubber industries',
#  'global trading marketing',
#  'green fresh lanka',
#  'green goddess',
#  'green lanka foliage exp',
#  'green pets',
#  'green soils',
#  'h m western',
#  'hami enterprises',
#  'hela clothing',
#  'helionne exp p l',
#  'highland flies sl',
#  'hirdaramani international exp',
#  'hydroponia del coco lanka',
#  'i m l',
#  'indochi',
#  'industrial clothings',
#  'intima',
#  'intl foodstuff  agri bio tech p l',
#  'isabela sea foods',
#  'island fish',
#  'island seafood exp',
#  'j lun trading services',
#  'j b enterprises',
#  'jacobi carbons lanka',
#  'jay jay mills',
#  'jay sea foods processing',
#  'jayarathna funeral directors',
#  'jesmin print',
#  'jf and i packaging',
#  'jffy products sl',
#  'john sea foods pl',
#  'jolanka',
#  'k m exp',
#  'kingstar global',
#  'korean sp a packaging',
#  'kramski lanka',
#  'lalan rubbers',
#  'lanka flora',
#  'lanka ornamental fish exp p',
#  'lanka walltile',
#  'laugfs corporation rubber',
#  'linea aqua',
#  'loadstar',
#  'lucky industries',
#  'lumbini aquaria wayamba',
#  'm j f exp',
#  'm k fisheries',
#  'm k lanka exp',
#  'm r m enterprises',
#  'mahir brothers',
#  'manisha',
#  'mariyam international',
#  'mas active trading',
#  'mas intimates',
#  'medical supplies division',
#  'merbok m d f lanka',
#  'merchant lanka',
#  'miami clothing',
#  'miami exp',
#  'midglobe trading',
#  'midland breeders',
#  'mike flora int',
#  'mountain hawk express',
#  'nandana tea factory',
#  'natural products exp',
#  'naturub exp international',
#  'neptune papers',
#  'next mfg',
#  'nidro supply',
#  'nikasa sea food',
#  'nippon maruchi lanka electronic p l',
#  'nor lanka mfg colombo',
#  'ocean fresh exp',
#  'ocean trade logistics',
#  'of smart shirts  lanka',
#  'omega line',
#  'orchid exp',
#  'oriental ocean express',
#  'oyezra exp',
#  'p n fernando',
#  'paradigm clothing',
#  'peduruhewa international',
#  'piramal glass ceylon',
#  'polytex garments',
#  'premasiri stores',
#  'prime star trading',
#  'prym intimates lanka private',
#  'pulses splitting  processing industries',
#  'quick tea',
#  'r m holdings',
#  'radiant gems international',
#  'randika aquarium farm house',
#  'randima exporters',
#  'ranlak exp',
#  'renuka agri foods',
#  'ru salu clothing',
#  'rufina exp',
#  's d see food exp',
#  's s exporters global',
#  's g exporters',
#  's g i lanka',
#  's r exp',
#  'sakthi international',
#  'samson rubber industries',
#  'samtessi brush mfg',
#  'sanmik food',
#  'serendib green',
#  'serendib horticulture techno  l',
#  'sewn exp',
#  'shekulanka foliage',
#  'shinwa lanka p',
#  'silver sand imp  exp',
#  'skynet worldwide express',
#  'south asia apparels',
#  'spear international',
#  'sri lankan airlines',
#  'stanthoneys coco',
#  'star flora',
#  'stewarts mfg',
#  'subash exp',
#  'sulak global exp',
#  'sumithra hasalaka pte',
#  't r exp international',
#  'timex garments',
#  'tradeasia',
#  'trans orbit logistics',
#  'trendywear adhikarigama',
#  'trischel fabric private',
#  'tropic frozen foods',
#  'tropical foliage',
#  'tropical shelfish',
#  'tropiflora',
#  'tropigreen horticulture',
#  'trust lanka logistics',
#  'tsuyoshi trading',
#  'udaya graphics',
#  'v t mfg',
#  'vechenson',
#  'vegiland exporters',
#  'vintage teas ceylon',
#  'vogue tex',
#  'w m de silva jewellers',
#  'watawala tea ceylon',
#  'weerasiri trading',
#  'western lanka fisheries',
#  'young an international lanka',
#  'zaaz international',
#  'zerendib motor enterprise',
#  'camso loadstar',
#  'a baur  copvt',
#  'agri lanka exp',
#  'agrilanka exp',
#  'agro coco tech',
#  'aitken spence hotel managements',
#  'alchemy boulders pte',
#  'allied horticultural enterprises pl',
#  'alwis agro exp',
#  'amalgamated international',
#  'angel aquarium',
#  'aquamarines international',
#  'asia bike industrial',
#  'avery dennison lanka',
#  'bridges worldwide',
#  'c n c clothing lanka',
#  'calico',
#  'ceylon tea bags',
#  'coco land',
#  'dabur lanka',
#  'daisen industries',
#  'damam k international',
#  'dee pee ex international',
#  'dreamco express',
#  'enine',
#  'ever green',
#  'expoworld buttons',
#  'forwardair courier',
#  'freshware exp imp enterprises',
#  'gallops trading',
#  'gamini k o',
#  'giko shipping',
#  'global sea foods',
#  'golden scalare business enterprise',
#  'granada suppliers',
#  'greatways apparels',
#  'greenfield bio plantations',
#  'gulf international maritime',
#  'hambantota trading',
#  'hayleys agro biotech',
#  'interex enterprises',
#  'kusang lanka',
#  'lanka garments mfg',
#  'lanka harness',
#  'lanka ioc',
#  'lanka minerals sand',
#  'lihini sea foods p',
#  'mao sheng',
#  'mas fabrics',
#  'mediequipment',
#  'meera sahibo and sons',
#  'miracle pets international',
#  'mullai foods',
#  'munasinghe',
#  'natural foliage',
#  'nature foliage',
#  'noritake lanka porcelain',
#  'north west fishery',
#  'ocean fresh',
#  'ominta aquarium international',
#  'prawn ceylon',
#  'quality food exporters',
#  'rainbow fashions',
#  'rajapakshe enterprises',
#  'ramya natural exp',
#  'rannara engineering services',
#  'ratnasiri sons',
#  'renuka organics',
#  'river view flora',
#  'royal air enterprises',
#  'ruvini aqua plants lanka',
#  's c s express',
#  'sadharitha agri farms exp',
#  'sarath aqua products',
#  'selakta international',
#  'serene international p',
#  'seylon aquatics',
#  'shiran clothing',
#  'skyway seafoods specialists',
#  'southern coast exp',
#  'spring valley fish farm',
#  'star food products',
#  'stassen exp',
#  'texprint lanka',
#  'thara textiles',
#  'tropic fishery',
#  'tropicoir lanka',
#  'udakara fresh products no',
#  'united flora',
#  'a f raymond',
#  'a s sea food',
#  'aggriko floral trading',
#  'aloy exp',
#  'anchor aquatic',
#  'apollo sea lagoon',
#  'aqualified international',
#  'aquatic nurseries',
#  'best agro',
#  'deep sea divers',
#  'deepam exp imp',
#  'dilan exp',
#  'dulvin flowers nursery',
#  'green field exp',
#  'greenline lanka',
#  'horticulture nlanka p l',
#  'kandurata d d exp',
#  'kestrel international',
#  'kumuduni enterprises',
#  'lisen lanka',
#  'lourdes aquarium',
#  'lumbini aquaria international',
#  'm r vegebrand exp',
#  'malthila',
#  'mareena fish farm',
#  'mariyam trading',
#  'new palace enterprises',
#  'nirma food court',
#  'norachchplai exp',
#  'ocean pets',
#  'orna fish',
#  'saram marine foods',
#  'serendib exp',
#  'silver dollar aquarium',
#  'sri lanka eye donation society',
#  'st annes factory',
#  't kasinathan t kasinathan',
#  'v s sea food',
#  'yarl achcha exp',
#  'zahra enterprises',
#  'a b d enterprises',
#  'a star traders',
#  'abans',
#  'abina and',
#  'accolade composite technologies',
#  'adamexpo',
#  'adamjee lukmanjee and sons',
#  'aero sense',
#  'agromet asia',
#  'aitken spence garments',
#  'akbar brothers',
#  'alankara s k r',
#  'ali brothers',
#  'alpha apparels',
#  'amazon corporation',
#  'american  efird lanka',
#  'aminovit private',
#  'amsafe bridport',
#  'anverally and sons',
#  'aqua ceylan p',
#  'aravind garments',
#  'asian aquarium',
#  'asian paints lanka',
#  'associated ceat',
#  'avon exp',
#  'bark ornament',
#  'beehive industries',
#  'benji',
#  'bio heva form factories',
#  'bischoff gamma lanka',
#  'bodyline',
#  'bonterra lanka',
#  'bt options',
#  'c c s lanka',
#  'ceat kelani international tyres',
#  'ceat kelani radials',
#  'ceilan coir products',
#  'cey coir substrates',
#  'ceyem commodities',
#  'ceylon foliage',
#  'ceylon organic virgin food pro p l',
#  'ceylon spice exp',
#  'ceylon tea marketing',
#  'cfl agro lanka',
#  'chas p hayley',
#  'courtaulds trading',
#  'crystal martin ceylon',
#  'crystal martin garment',
#  'd  c trading',
#  'd r exp',
#  'daya apparel export',
#  'deen sons a m s',
#  'design studio mfg',
#  'designer exp',
#  'dipped products',
#  'dpl premier gloves',
#  'dt exp imp',
#  'elegant knitting',
#  'elphis lanka',
#  'emdee exp private',
#  'emjay international',
#  'empire teas',
#  'energizer lanka',
#  'eskimo fashion knitwear private',
#  'essilor lanka',
#  'eswaran brothers exp',
#  'expolanka teas',
#  'ezy distribution',
#  'felicitas trading',
#  'fergasam garments industries',
#  'finest tea exp',
#  'fits aviation',
#  'flemingo duty free',
#  'gem paradise',
#  'geocyc',
#  'george steuart teas',
#  'global intimates',
#  'globe xpress international',
#  'golden flies',
#  'gopsons lanka private',
#  'green guard foliage',
#  'green horizon enterprises',
#  'grossart',
#  'gurind accor',
#  'h e engineering',
#  'h h exp imp',
#  'h p n international',
#  'h s b exporters',
#  'hansel textil lanka',
#  'hanwella rubber products',
#  'haycarb',
#  'heritage teas',
#  'hjs condiments',
#  'house of design',
#  'imperial spices',
#  'imperial tea exp',
#  'impex corparation',
#  'industrial clothing',
#  'interfashion',
#  'interlook cargo clearing forwardi',
#  'internl trimm labels lanka  l',
#  'intl foodstuff',
#  'isin lanka',
#  'jvgokal ceylon',
#  'jafferjee brothers',
#  'jafferjee brothers exp',
#  'jayabima anjana buttons',
#  'jc enterprises',
#  'jeff garments international',
#  'judesan sea foods',
#  'kaira distribution',
#  'kash garments',
#  'kegalle plantations',
#  'kelani cables',
#  'kemin exp',
#  'kokospeat exp',
#  'kosan crisplant lanka',
#  'lanka agro processing',
#  'lanka fishing flies',
#  'lanka green growers',
#  'lanka hiqu',
#  'latex green',
#  'lion brewery ceylon',
#  'm h sudesh traders',
#  'm j f beverages',
#  'm j f teas',
#  'mabroc teas',
#  'madu nadee interational',
#  'mahmood tea international',
#  'marine wealth',
#  'marsylka mfg lanka',
#  'may  ceylon',
#  'meezan',
#  'metshu exp',
#  'mihisara exporters',
#  'motherson electrical wires lanka',
#  'mount lavinia hotel',
#  'mrf lanka',
#  'n d c exp',
#  'nasnaimpex garments industries',
#  'nature lanka exp',
#  'neoprex',
#  'new dehara trading',
#  'nimal auto suppliers exp',
#  'nithya paper  board lanka',
#  'nobles mfg',
#  'nobleswear',
#  'noratel international',
#  'north manufactcuring',
#  'norwood fashion',
#  'noyon lanka',
#  'okaya lanka',
#  'orit trading lanka',
#  'pallewela holdings',
#  'penguin sportswear',
#  'perstaff holdings',
#  'poly creations',
#  'prasanna liyanarachchi holdings pl',
#  'prima ceylon',
#  'pripa organic colombo',
#  'priyantha gems',
#  'quality food suppliers',
#  'quantum clothing lanka',
#  'quick grow natural products',
#  'r r i sea foods',
#  'rabeena foods',
#  'ramya horticulture',
#  'ranfer international',
#  'ranfer teas',
#  'richlight exp',
#  'riococo lanka',
#  'roots breath lanka',
#  'rose mill fibre grinders',
#  's a m',
#  'saaraketha holdings',
#  'sab sala associates',
#  'sampath bank',
#  'samson reclaim rubber d samson',
#  'samudra aquarist partners',
#  'sanchia',
#  'sansu lanka',
#  'serendib flour mills',
#  'shanjit international',
#  'shipping management logistics pt',
#  'shore to shore',
#  'silueta',
#  'sinca exp',
#  'sindbad',
#  'sintesi',
#  'sml dualplast lanka',
#  'softlogic information technologies',
#  'southern sea foods',
#  'sri lanka telecom',
#  'stretchline',
#  'stylish garment',
#  'suganth atollinx international pl',
#  'suganth international',
#  'sumithra garments pte',
#  'sunshine tea',
#  'swiss cut design',
#  'taprobane sea foodspvt',
#  'tea tang',
#  'textured jersey lanka',
#  'trend setters',
#  'tropical findings',
#  'tropical island commodities',
#  'trust gems holding',
#  'ukwatta exp',
#  'unichela',
#  'unilever lipton ceylon',
#  'union commodities',
#  'union imp exp',
#  'up town international',
#  'van rees ceylon',
#  'vibrant underwater world',
#  'waguruwela oil mills',
#  'wayamba lanka coco mfg',
#  'winter quilts',
#  'workwear lanka',
#  'a m rahim',
#  'a n g e aqua marine international p l',
#  'a s agri exp',
#  'achini trading',
#  'agalawatte plantations',
#  'ally weerasinghe',
#  'almar teas',
#  'almar trading  pte',
#  'alpha apperals',
#  'aqua dynamics',
#  'atg lanka',
#  'avomark international p l',
#  'balaji ventures lanka',
#  'barbara sansoni exp',
#  'basilur tea exp',
#  'bio foods',
#  'bogala graphite lanka',
#  'botanicoir lanka',
#  'brandix textiles',
#  'bratex',
#  'canberg lanka',
#  'carlton garments',
#  'ceylon coir fibre industries  l',
#  'ceylon natural coco',
#  'ceylon oxygen',
#  'ceylon rubber indpvt',
#  'ceylon tea land',
#  'ceyquartz mbi',
#  'cinna hotel management services',
#  'classic garments pte',
#  'cocogreen united kingdom lanka',
#  'cocopel lanka',
#  'colombo quality coir products',
#  'comfort bedding internationala p l',
#  'commercial bank of ceylon',
#  'contrinex ceylon',
#  'cosmic poly plast',
#  'courtaulds clothing dambadeniya',
#  'ctp pre packed exp',
#  'd  g spice exp',
#  'd 2 clothing',
#  'd s l lanka',
#  'd t w international',
#  'dlk spice exp',
#  'de la rue lanka currency  secu p l i p z biyagama malwana',
#  'dimara distributors',
#  'durtek lanka',
#  'e m e engineering lanka',
#  'eam maliban texts mahiyanganaya pl',
#  'ecochem',
#  'enterprising enterprises',
#  'ever green exp',
#  'fairdeal trading',
#  'falcon trading',
#  'finlays colombo',
#  'flex film international',
#  'flintec transducers',
#  'friends poly packagaing',
#  'gp de silva  sons international',
#  'galuku hydroponics',
#  'global clothing international',
#  'grow soil substrates',
#  'growrite substrates',
#  'haifa traders',
#  'hands international intimates  l',
#  'haskel garments',
#  'hayleys free zone',
#  'herbert stephan lanka',
#  'horombawa coir products',
#  'innovative knitwear',
#  'inter tea',
#  'intern pulses processing induspl',
#  'intexmode',
#  'intl precision moulds tools p',
#  'ishana exp',
#  'j m a imp exp lanka',
#  'j a de silva',
#  'jaindi exp',
#  'jay jay mills lanka',
#  'kmk seafoods',
#  'koiralive exp',
#  'l c packaging industries',
#  'lakro enterprises',
#  'lalan eco latex',
#  'lanka coco products',
#  'lanka leather fashion',
#  'lanka shipping logistics',
#  'leoch lanka',
#  'm c enterprises',
#  'macson mesh industries',
#  'manchiee de coco products',
#  'mas active',
#  'meezan ancoombra plantations',
#  'melray international',
#  'msh packaing industries',
#  'mufaddal traders',
#  'multi fish lanka',
#  'multy coco products',
#  'n exp imp',
#  'nasna imp  exp garments industries',
#  'natural collections',
#  'nestle lanka',
#  'new asia traders',
#  'nikini automation systems',
#  'nippon knit',
#  'orava',
#  'orient trading',
#  'pearl lanka kandy',
#  'peoples organi for development imp exp',
#  'piyadasa k k koralge fibre expoters',
#  'plant lipids lanka',
#  'praventure international',
#  'qualitea ceylon',
#  'quality fish exp',
#  'r k s lanka',
#  'rainbow aquarium isuru',
#  'rainbow foods',
#  'rainco industries',
#  'raux brothers',
#  'ravi industries',
#  'rawfood sri lanka galgoda',
#  'regal calibre lk',
#  'regency teas',
#  'reliance diamond tool    south asia g m',
#  'richard pieris natural foams',
#  'rjv international',
#  's and s lanka gloves',
#  's c printing international',
#  'sd chemicals',
#  's n industries',
#  'safex',
#  'sampath associates internl',
#  'samson bikes',
#  'sanjeewa aquatics',
#  'sathuta international',
#  'sds spices',
#  'seijitsu lanka',
#  'serendipol',
#  'shums',
#  'silvermill natural beverages',
#  'sirio',
#  'sirisanda timber products exp',
#  'skyline baseball',
#  'sobi imp exp',
#  'sol trim international',
#  'south asia granite marbel',
#  'south asia textile industries lanka',
#  'southern spars international p',
#  'spedicon logistics',
#  'spice link',
#  'star fashion clothing',
#  'straintec',
#  'stretch line',
#  'summer plants',
#  'sun sauru',
#  'sunray aquatics',
#  't print',
#  'tharanganee garments',
#  'three acre farms',
#  'toyo cushion lanka',
#  'trelleborg lanka',
#  'tropical sea foods exp',
#  'trump coir products',
#  'udara lanka coir exp',
#  'union apperals',
#  'uniworld teas',
#  'variosystems',
#  'wacoal timex',
#  'western paper industries',
#  'wilkins spence packaging lanka pv l',
#  'ykk lanka',
#  'a f jones exporters ceylon',
#  'abhiman apparel',
#  'aes kelanitissa',
#  'agro nutrition',
#  'alloy fabricators international p l',
#  'alpha exp',
#  'anods cocoa',
#  'ansell textiles lanka',
#  'anura wijemanne associates',
#  'arpitalian compact soles',
#  'asian cutting lanka',
#  'aslan conchshells enterprises',
#  'aura solutions',
#  'b p l teas',
#  'b w holding',
#  'beira brush',
#  'black tea exp',
#  'boehm and leckner multimoulds',
#  'bogawantalawa plantation teas',
#  'capitol lanka',
#  'ceylon 2 u foods',
#  'ceylon agro industries',
#  'ceylon biscuits lanka exp   cbl exp',
#  'ceylon biscuits',
#  'ceylon commodity marketing',
#  'ceylon pencil',
#  'ceylon quartz industries',
#  'christina packaging accessories p',
#  'city cycle industries',
#  'clarion logistics',
#  'classic teas',
#  'cocotech exp lanka',
#  'colmans garments industries  l',
#  'colombo stone industries',
#  'colossus',
#  'concord apparel',
#  'consarc',
#  'crystal martin central',
#  'dani foods lanka',
#  'dial textile industries',
#  'dialog axiata',
#  'diamond dreams',
#  'dole lanka',
#  'eastern merchants',
#  'edna cocoa products',
#  'ellawala exp',
#  'elsteel',
#  'embody trading',
#  'eoas organics private limited',
#  'etna trade links',
#  'euro scan exp',
#  'exotic aquarium',
#  'fairmount fashion',
#  'favourite international exp l',
#  'flexi print',
#  'fresh tea exp',
#  'fulgar lanka',
#  'gamma lanka garment industr',
#  'global sports lanka',
#  'gospel house handi crafts',
#  'green farms',
#  'green global imp  exp',
#  'green grow exp',
#  'green scape coir exp',
#  'green view international',
#  'greenstone',
#  'hatton national bank',
#  'hayleys energy services lanka  l',
#  'hddes extracts',
#  'hemas mfg',
#  'heritage teas premium services',
#  'hicom international aquaculture',
#  'hva foods',
#  'i p m t lanka',
#  'intex lanka',
#  'isabella  private',
#  'island exp',
#  'j e p australia',
#  'jawad interanational',
#  'jumeirah lanka',
#  'kik lanka',
#  'kalaro',
#  'kalnara commodities',
#  'kanara exp',
#  'kathiravan imp exp',
#  'keana',
#  'kent display',
#  'kokosfibre exp',
#  'kushuhara trading',
#  'l  s engineering',
#  'lbspices trading',
#  'lak methodic',
#  'lanka brush exp',
#  'lanka canneries',
#  'lanka commodity trading',
#  'lanka maritime services',
#  'lanka pets aquatics',
#  'libra exp',
#  'link natural products',
#  'ltl projects',
#  'lumbini tea exp',
#  'mainettech lanka',
#  'manikto gem',
#  'mapa lalan',
#  'marangoni industrial tyres lanka',
#  'master tea  spices',
#  'mccallum nurseries global',
#  'merandiv',
#  'microcells',
#  'midaya ceramic',
#  'millennium informtn technologies ld',
#  'minra garmnets',
#  'modern printing design lanka',
#  'morex lanka',
#  'n j fishing exp',
#  'n m k agro industries',
#  'naturub lingerie accessories',
#  'new colombo aquarium',
#  'new world gem',
#  'nico battery mfg',
#  'north line asia',
#  'ocean lanka',
#  'of singworld lanka',
#  'of trendywear',
#  'omega green',
#  'orchid collection',
#  'orel corporation',
#  'oxley threads lanka',
#  'p c e lanka',
#  'p a enterpises',
#  'pms traders',
#  'permess international',
#  'plastipak industrial textiles',
#  'plastipak lanka',
#  'presstona tiles lanka',
#  'prestige quality international',
#  'printcare packaging',
#  'printcare secure',
#  'printcare universal',
#  'r j v international',
#  'r p c polymers',
#  'raihaan centre',
#  'rainwear',
#  'rajarata food products',
#  'rakshaa',
#  'randunu fabric',
#  'ranjithaa pulses splitting',
#  'reality management services',
#  'renuka agro exp',
#  'renuka teas ceylon',
#  'rileys',
#  'rinstrum',
#  'roshan exp',
#  'ruhunu imp  exp',
#  'ruky enterprises',
#  's  d associates',
#  's l coco fibre mfg copvt',
#  's st clair teas',
#  's r metals',
#  'sasilva  sons lanka',
#  'sadeepa enterprises',
#  'salike',
#  'samarasinghe brothers',
#  'samson international',
#  'samson rubber products',
#  'sancta maria coir products',
#  'saru international',
#  'scanwell logistics colombo',
#  'screenline',
#  'search lanka travels cons',
#  'seneviratne bandula',
#  'senok aviation',
#  'serenco trading',
#  'shanghai steels',
#  'siddhalepa exp',
#  'snacka lanka',
#  'sri lanka handicrafts board',
#  'stone asia',
#  'superfine teas',
#  't s buttons lanka',
#  'tea  herb',
#  'tea packs',
#  'techstar packaging',
#  'texorn',
#  'the green rubber',
#  'the green rubber toy',
#  'the island watch',
#  'the leaf',
#  'trelleborg wheel systems lanka p l',
#  'triple safety',
#  'tropical abundance',
#  'tropical green',
#  'uk beverages',
#  'united tobacco processing',
#  'united tractor  equipemnt',
#  'usui lanka',
#  'venture hotel supplies',
#  'walters bay bogawantalawa estates',
#  'warna exporters',
#  'wayamba coco peat galaudawattu',
#  'wichy plantation',
#  'winmark international',
#  'woodman lanka',
#  'worldwide commodities',
#  'yus exim',
#  'zigo technology',
#  'as chatoor',
#  'acl cables',
#  'agio tobacco processing',
#  'akai fasteners',
#  'aramco polythene',
#  'arcadian sourcing',
#  'asons',
#  'ayubowan gift collection',
#  'b s h ventures',
#  'beira parawood products',
#  'benham international',
#  'bio extracts',
#  'bismil holdings',
#  'boumy lanka',
#  'brenntag lanka',
#  'carbon activated corporation lanka',
#  'cbl natural foods',
#  'ceramic world',
#  'ceylon chain mfg',
#  'ceylon fresh teaspvt',
#  'ceylon machine twisted fibre',
#  'ceylon recycle industries',
#  'ceylon victorias teas',
#  'chevron lubricants lanka',
#  'cliftex industriesprivate',
#  'coco house',
#  'coir project international lanka',
#  'crystal martin garments',
#  'cwt globelink colombo',
#  'd p l universal gloves',
#  'd2 clothing',
#  'dankotuwa porcelain',
#  'darwish trading',
#  'david pieris motor',
#  'dellogistics   no',
#  'derana international',
#  'dhl global forwarding lanka',
#  'dialog broadband networks',
#  'diamond international lanka',
#  'diesel and motor engineering',
#  'dilshara international',
#  'doctor dona exp importers pl',
#  'dsl global',
#  'dynamic tecnologies',
#  'eco engineers',
#  'eco soil substrates',
#  'eden pharmaceuticals',
#  'embilmeegama tea',
#  'energy generators',
#  'eu retec',
#  'euro substrates',
#  'everest industrial lanka',
#  'expack corrugated cartons',
#  'ezzy sails lanka',
#  'fantasia elastics',
#  'fgm lanka',
#  ...]

# %%
# generte firm ids
ids = np.arange(1,len(names)+1,1)
print("min: ", ids.min())
print("max: ", ids.max())
# Out:
# min:  1
# max:  14234

# %%
# maps ids to names
maps = {k:v for k,v in zip(names, ids)}
maps
# Out:
# {'a class trading': 1,
#  'a k y lanka': 2,
#  'a r freight care services': 3,
#  'ace international express': 4,
#  'aero dynamics': 5,
#  'akbar bros': 6,
#  'aldora exporters': 7,
#  'alpex marine': 8,
#  'amagi exp': 9,
#  'ansell lanka': 10,
#  'antron express': 11,
#  'ap lanka': 12,
#  'aqua packaging': 13,
#  'aramex lanka': 14,
#  'arrow sea food': 15,
#  'associated speciality rubbers': 16,
#  'atheeb exp': 17,
#  'beyond exp': 18,
#  'bio grow lanka': 19,
#  'borneo exotics': 20,
#  'brandix apparel': 21,
#  'britannia garment packaging p l': 22,
#  'c w mackie': 23,
#  'c r exp': 24,
#  'capitol overseas': 25,
#  'central rubber': 26,
#  'ceylon fresh seafood': 27,
#  'ceylon natural exp': 28,
#  'ceylon paper pottery': 29,
#  'ceylon pest control': 30,
#  'ceylon tea services': 31,
#  'ceymac rubber': 32,
#  'chiefway lanka': 33,
#  'coats thread exp': 34,
#  'coco land lanka': 35,
#  'colombo dockyard': 36,
#  'commercial exp': 37,
#  'consolidated business systems': 38,
#  'csk exp': 39,
#  'd h l keels': 40,
#  'dasa trade center': 41,
#  'decor foliage rathnasiriya meegahamula': 42,
#  'delta gems': 43,
#  'dero exp international': 44,
#  'development interplan ceylon': 45,
#  'diamond cutters': 46,
#  'dilarshad enterprise': 47,
#  'dilcoir mills': 48,
#  'divine worldwide': 49,
#  'dkw aqua international': 50,
#  'dracina plant nursery': 51,
#  'e v r exp': 52,
#  'eam maliban textiles': 53,
#  'earthscape': 54,
#  'eastern allied agencies': 55,
#  'elastomeric engineering': 56,
#  'emar pharma': 57,
#  'emjay international m m center': 58,
#  'eva lanka': 59,
#  'exp global distribution center': 60,
#  'expolanka freight': 61,
#  'fairmount apparels': 62,
#  'fascination exp': 63,
#  'for personal effect exporters': 64,
#  'foundation garments': 65,
#  'frontier holdings': 66,
#  'future world lanka': 67,
#  'garment services meegoda': 68,
#  'ghim li lanka': 69,
#  'gislaved gummi lanka': 70,
#  'global rubber industries': 71,
#  'global trading marketing': 72,
#  'green fresh lanka': 73,
#  'green goddess': 74,
#  'green lanka foliage exp': 75,
#  'green pets': 76,
#  'green soils': 77,
#  'h m western': 78,
#  'hami enterprises': 79,
#  'hela clothing': 80,
#  'helionne exp p l': 81,
#  'highland flies sl': 82,
#  'hirdaramani international exp': 83,
#  'hydroponia del coco lanka': 84,
#  'i m l': 85,
#  'indochi': 86,
#  'industrial clothings': 87,
#  'intima': 88,
#  'intl foodstuff  agri bio tech p l': 89,
#  'isabela sea foods': 90,
#  'island fish': 91,
#  'island seafood exp': 92,
#  'j lun trading services': 93,
#  'j b enterprises': 94,
#  'jacobi carbons lanka': 95,
#  'jay jay mills': 96,
#  'jay sea foods processing': 97,
#  'jayarathna funeral directors': 98,
#  'jesmin print': 99,
#  'jf and i packaging': 100,
#  'jffy products sl': 101,
#  'john sea foods pl': 102,
#  'jolanka': 103,
#  'k m exp': 104,
#  'kingstar global': 105,
#  'korean sp a packaging': 106,
#  'kramski lanka': 107,
#  'lalan rubbers': 108,
#  'lanka flora': 109,
#  'lanka ornamental fish exp p': 110,
#  'lanka walltile': 111,
#  'laugfs corporation rubber': 112,
#  'linea aqua': 113,
#  'loadstar': 114,
#  'lucky industries': 115,
#  'lumbini aquaria wayamba': 116,
#  'm j f exp': 117,
#  'm k fisheries': 118,
#  'm k lanka exp': 119,
#  'm r m enterprises': 120,
#  'mahir brothers': 121,
#  'manisha': 122,
#  'mariyam international': 123,
#  'mas active trading': 124,
#  'mas intimates': 125,
#  'medical supplies division': 126,
#  'merbok m d f lanka': 127,
#  'merchant lanka': 128,
#  'miami clothing': 129,
#  'miami exp': 130,
#  'midglobe trading': 131,
#  'midland breeders': 132,
#  'mike flora int': 133,
#  'mountain hawk express': 134,
#  'nandana tea factory': 135,
#  'natural products exp': 136,
#  'naturub exp international': 137,
#  'neptune papers': 138,
#  'next mfg': 139,
#  'nidro supply': 140,
#  'nikasa sea food': 141,
#  'nippon maruchi lanka electronic p l': 142,
#  'nor lanka mfg colombo': 143,
#  'ocean fresh exp': 144,
#  'ocean trade logistics': 145,
#  'of smart shirts  lanka': 146,
#  'omega line': 147,
#  'orchid exp': 148,
#  'oriental ocean express': 149,
#  'oyezra exp': 150,
#  'p n fernando': 151,
#  'paradigm clothing': 152,
#  'peduruhewa international': 153,
#  'piramal glass ceylon': 154,
#  'polytex garments': 155,
#  'premasiri stores': 156,
#  'prime star trading': 157,
#  'prym intimates lanka private': 158,
#  'pulses splitting  processing industries': 159,
#  'quick tea': 160,
#  'r m holdings': 161,
#  'radiant gems international': 162,
#  'randika aquarium farm house': 163,
#  'randima exporters': 164,
#  'ranlak exp': 165,
#  'renuka agri foods': 166,
#  'ru salu clothing': 167,
#  'rufina exp': 168,
#  's d see food exp': 169,
#  's s exporters global': 170,
#  's g exporters': 171,
#  's g i lanka': 172,
#  's r exp': 173,
#  'sakthi international': 174,
#  'samson rubber industries': 175,
#  'samtessi brush mfg': 176,
#  'sanmik food': 177,
#  'serendib green': 178,
#  'serendib horticulture techno  l': 179,
#  'sewn exp': 180,
#  'shekulanka foliage': 181,
#  'shinwa lanka p': 182,
#  'silver sand imp  exp': 183,
#  'skynet worldwide express': 184,
#  'south asia apparels': 185,
#  'spear international': 186,
#  'sri lankan airlines': 187,
#  'stanthoneys coco': 188,
#  'star flora': 189,
#  'stewarts mfg': 190,
#  'subash exp': 191,
#  'sulak global exp': 192,
#  'sumithra hasalaka pte': 193,
#  't r exp international': 194,
#  'timex garments': 195,
#  'tradeasia': 196,
#  'trans orbit logistics': 197,
#  'trendywear adhikarigama': 198,
#  'trischel fabric private': 199,
#  'tropic frozen foods': 200,
#  'tropical foliage': 201,
#  'tropical shelfish': 202,
#  'tropiflora': 203,
#  'tropigreen horticulture': 204,
#  'trust lanka logistics': 205,
#  'tsuyoshi trading': 206,
#  'udaya graphics': 207,
#  'v t mfg': 208,
#  'vechenson': 209,
#  'vegiland exporters': 210,
#  'vintage teas ceylon': 211,
#  'vogue tex': 212,
#  'w m de silva jewellers': 213,
#  'watawala tea ceylon': 214,
#  'weerasiri trading': 215,
#  'western lanka fisheries': 216,
#  'young an international lanka': 217,
#  'zaaz international': 218,
#  'zerendib motor enterprise': 219,
#  'camso loadstar': 220,
#  'a baur  copvt': 221,
#  'agri lanka exp': 222,
#  'agrilanka exp': 223,
#  'agro coco tech': 224,
#  'aitken spence hotel managements': 225,
#  'alchemy boulders pte': 226,
#  'allied horticultural enterprises pl': 227,
#  'alwis agro exp': 228,
#  'amalgamated international': 229,
#  'angel aquarium': 230,
#  'aquamarines international': 231,
#  'asia bike industrial': 232,
#  'avery dennison lanka': 233,
#  'bridges worldwide': 234,
#  'c n c clothing lanka': 235,
#  'calico': 236,
#  'ceylon tea bags': 237,
#  'coco land': 238,
#  'dabur lanka': 239,
#  'daisen industries': 240,
#  'damam k international': 241,
#  'dee pee ex international': 242,
#  'dreamco express': 243,
#  'enine': 244,
#  'ever green': 245,
#  'expoworld buttons': 246,
#  'forwardair courier': 247,
#  'freshware exp imp enterprises': 248,
#  'gallops trading': 249,
#  'gamini k o': 250,
#  'giko shipping': 251,
#  'global sea foods': 252,
#  'golden scalare business enterprise': 253,
#  'granada suppliers': 254,
#  'greatways apparels': 255,
#  'greenfield bio plantations': 256,
#  'gulf international maritime': 257,
#  'hambantota trading': 258,
#  'hayleys agro biotech': 259,
#  'interex enterprises': 260,
#  'kusang lanka': 261,
#  'lanka garments mfg': 262,
#  'lanka harness': 263,
#  'lanka ioc': 264,
#  'lanka minerals sand': 265,
#  'lihini sea foods p': 266,
#  'mao sheng': 267,
#  'mas fabrics': 268,
#  'mediequipment': 269,
#  'meera sahibo and sons': 270,
#  'miracle pets international': 271,
#  'mullai foods': 272,
#  'munasinghe': 273,
#  'natural foliage': 274,
#  'nature foliage': 275,
#  'noritake lanka porcelain': 276,
#  'north west fishery': 277,
#  'ocean fresh': 278,
#  'ominta aquarium international': 279,
#  'prawn ceylon': 280,
#  'quality food exporters': 281,
#  'rainbow fashions': 282,
#  'rajapakshe enterprises': 283,
#  'ramya natural exp': 284,
#  'rannara engineering services': 285,
#  'ratnasiri sons': 286,
#  'renuka organics': 287,
#  'river view flora': 288,
#  'royal air enterprises': 289,
#  'ruvini aqua plants lanka': 290,
#  's c s express': 291,
#  'sadharitha agri farms exp': 292,
#  'sarath aqua products': 293,
#  'selakta international': 294,
#  'serene international p': 295,
#  'seylon aquatics': 296,
#  'shiran clothing': 297,
#  'skyway seafoods specialists': 298,
#  'southern coast exp': 299,
#  'spring valley fish farm': 300,
#  'star food products': 301,
#  'stassen exp': 302,
#  'texprint lanka': 303,
#  'thara textiles': 304,
#  'tropic fishery': 305,
#  'tropicoir lanka': 306,
#  'udakara fresh products no': 307,
#  'united flora': 308,
#  'a f raymond': 309,
#  'a s sea food': 310,
#  'aggriko floral trading': 311,
#  'aloy exp': 312,
#  'anchor aquatic': 313,
#  'apollo sea lagoon': 314,
#  'aqualified international': 315,
#  'aquatic nurseries': 316,
#  'best agro': 317,
#  'deep sea divers': 318,
#  'deepam exp imp': 319,
#  'dilan exp': 320,
#  'dulvin flowers nursery': 321,
#  'green field exp': 322,
#  'greenline lanka': 323,
#  'horticulture nlanka p l': 324,
#  'kandurata d d exp': 325,
#  'kestrel international': 326,
#  'kumuduni enterprises': 327,
#  'lisen lanka': 328,
#  'lourdes aquarium': 329,
#  'lumbini aquaria international': 330,
#  'm r vegebrand exp': 331,
#  'malthila': 332,
#  'mareena fish farm': 333,
#  'mariyam trading': 334,
#  'new palace enterprises': 335,
#  'nirma food court': 336,
#  'norachchplai exp': 337,
#  'ocean pets': 338,
#  'orna fish': 339,
#  'saram marine foods': 340,
#  'serendib exp': 341,
#  'silver dollar aquarium': 342,
#  'sri lanka eye donation society': 343,
#  'st annes factory': 344,
#  't kasinathan t kasinathan': 345,
#  'v s sea food': 346,
#  'yarl achcha exp': 347,
#  'zahra enterprises': 348,
#  'a b d enterprises': 349,
#  'a star traders': 350,
#  'abans': 351,
#  'abina and': 352,
#  'accolade composite technologies': 353,
#  'adamexpo': 354,
#  'adamjee lukmanjee and sons': 355,
#  'aero sense': 356,
#  'agromet asia': 357,
#  'aitken spence garments': 358,
#  'akbar brothers': 359,
#  'alankara s k r': 360,
#  'ali brothers': 361,
#  'alpha apparels': 362,
#  'amazon corporation': 363,
#  'american  efird lanka': 364,
#  'aminovit private': 365,
#  'amsafe bridport': 366,
#  'anverally and sons': 367,
#  'aqua ceylan p': 368,
#  'aravind garments': 369,
#  'asian aquarium': 370,
#  'asian paints lanka': 371,
#  'associated ceat': 372,
#  'avon exp': 373,
#  'bark ornament': 374,
#  'beehive industries': 375,
#  'benji': 376,
#  'bio heva form factories': 377,
#  'bischoff gamma lanka': 378,
#  'bodyline': 379,
#  'bonterra lanka': 380,
#  'bt options': 381,
#  'c c s lanka': 382,
#  'ceat kelani international tyres': 383,
#  'ceat kelani radials': 384,
#  'ceilan coir products': 385,
#  'cey coir substrates': 386,
#  'ceyem commodities': 387,
#  'ceylon foliage': 388,
#  'ceylon organic virgin food pro p l': 389,
#  'ceylon spice exp': 390,
#  'ceylon tea marketing': 391,
#  'cfl agro lanka': 392,
#  'chas p hayley': 393,
#  'courtaulds trading': 394,
#  'crystal martin ceylon': 395,
#  'crystal martin garment': 396,
#  'd  c trading': 397,
#  'd r exp': 398,
#  'daya apparel export': 399,
#  'deen sons a m s': 400,
#  'design studio mfg': 401,
#  'designer exp': 402,
#  'dipped products': 403,
#  'dpl premier gloves': 404,
#  'dt exp imp': 405,
#  'elegant knitting': 406,
#  'elphis lanka': 407,
#  'emdee exp private': 408,
#  'emjay international': 409,
#  'empire teas': 410,
#  'energizer lanka': 411,
#  'eskimo fashion knitwear private': 412,
#  'essilor lanka': 413,
#  'eswaran brothers exp': 414,
#  'expolanka teas': 415,
#  'ezy distribution': 416,
#  'felicitas trading': 417,
#  'fergasam garments industries': 418,
#  'finest tea exp': 419,
#  'fits aviation': 420,
#  'flemingo duty free': 421,
#  'gem paradise': 422,
#  'geocyc': 423,
#  'george steuart teas': 424,
#  'global intimates': 425,
#  'globe xpress international': 426,
#  'golden flies': 427,
#  'gopsons lanka private': 428,
#  'green guard foliage': 429,
#  'green horizon enterprises': 430,
#  'grossart': 431,
#  'gurind accor': 432,
#  'h e engineering': 433,
#  'h h exp imp': 434,
#  'h p n international': 435,
#  'h s b exporters': 436,
#  'hansel textil lanka': 437,
#  'hanwella rubber products': 438,
#  'haycarb': 439,
#  'heritage teas': 440,
#  'hjs condiments': 441,
#  'house of design': 442,
#  'imperial spices': 443,
#  'imperial tea exp': 444,
#  'impex corparation': 445,
#  'industrial clothing': 446,
#  'interfashion': 447,
#  'interlook cargo clearing forwardi': 448,
#  'internl trimm labels lanka  l': 449,
#  'intl foodstuff': 450,
#  'isin lanka': 451,
#  'jvgokal ceylon': 452,
#  'jafferjee brothers': 453,
#  'jafferjee brothers exp': 454,
#  'jayabima anjana buttons': 455,
#  'jc enterprises': 456,
#  'jeff garments international': 457,
#  'judesan sea foods': 458,
#  'kaira distribution': 459,
#  'kash garments': 460,
#  'kegalle plantations': 461,
#  'kelani cables': 462,
#  'kemin exp': 463,
#  'kokospeat exp': 464,
#  'kosan crisplant lanka': 465,
#  'lanka agro processing': 466,
#  'lanka fishing flies': 467,
#  'lanka green growers': 468,
#  'lanka hiqu': 469,
#  'latex green': 470,
#  'lion brewery ceylon': 471,
#  'm h sudesh traders': 472,
#  'm j f beverages': 473,
#  'm j f teas': 474,
#  'mabroc teas': 475,
#  'madu nadee interational': 476,
#  'mahmood tea international': 477,
#  'marine wealth': 478,
#  'marsylka mfg lanka': 479,
#  'may  ceylon': 480,
#  'meezan': 481,
#  'metshu exp': 482,
#  'mihisara exporters': 483,
#  'motherson electrical wires lanka': 484,
#  'mount lavinia hotel': 485,
#  'mrf lanka': 486,
#  'n d c exp': 487,
#  'nasnaimpex garments industries': 488,
#  'nature lanka exp': 489,
#  'neoprex': 490,
#  'new dehara trading': 491,
#  'nimal auto suppliers exp': 492,
#  'nithya paper  board lanka': 493,
#  'nobles mfg': 494,
#  'nobleswear': 495,
#  'noratel international': 496,
#  'north manufactcuring': 497,
#  'norwood fashion': 498,
#  'noyon lanka': 499,
#  'okaya lanka': 500,
#  'orit trading lanka': 501,
#  'pallewela holdings': 502,
#  'penguin sportswear': 503,
#  'perstaff holdings': 504,
#  'poly creations': 505,
#  'prasanna liyanarachchi holdings pl': 506,
#  'prima ceylon': 507,
#  'pripa organic colombo': 508,
#  'priyantha gems': 509,
#  'quality food suppliers': 510,
#  'quantum clothing lanka': 511,
#  'quick grow natural products': 512,
#  'r r i sea foods': 513,
#  'rabeena foods': 514,
#  'ramya horticulture': 515,
#  'ranfer international': 516,
#  'ranfer teas': 517,
#  'richlight exp': 518,
#  'riococo lanka': 519,
#  'roots breath lanka': 520,
#  'rose mill fibre grinders': 521,
#  's a m': 522,
#  'saaraketha holdings': 523,
#  'sab sala associates': 524,
#  'sampath bank': 525,
#  'samson reclaim rubber d samson': 526,
#  'samudra aquarist partners': 527,
#  'sanchia': 528,
#  'sansu lanka': 529,
#  'serendib flour mills': 530,
#  'shanjit international': 531,
#  'shipping management logistics pt': 532,
#  'shore to shore': 533,
#  'silueta': 534,
#  'sinca exp': 535,
#  'sindbad': 536,
#  'sintesi': 537,
#  'sml dualplast lanka': 538,
#  'softlogic information technologies': 539,
#  'southern sea foods': 540,
#  'sri lanka telecom': 541,
#  'stretchline': 542,
#  'stylish garment': 543,
#  'suganth atollinx international pl': 544,
#  'suganth international': 545,
#  'sumithra garments pte': 546,
#  'sunshine tea': 547,
#  'swiss cut design': 548,
#  'taprobane sea foodspvt': 549,
#  'tea tang': 550,
#  'textured jersey lanka': 551,
#  'trend setters': 552,
#  'tropical findings': 553,
#  'tropical island commodities': 554,
#  'trust gems holding': 555,
#  'ukwatta exp': 556,
#  'unichela': 557,
#  'unilever lipton ceylon': 558,
#  'union commodities': 559,
#  'union imp exp': 560,
#  'up town international': 561,
#  'van rees ceylon': 562,
#  'vibrant underwater world': 563,
#  'waguruwela oil mills': 564,
#  'wayamba lanka coco mfg': 565,
#  'winter quilts': 566,
#  'workwear lanka': 567,
#  'a m rahim': 568,
#  'a n g e aqua marine international p l': 569,
#  'a s agri exp': 570,
#  'achini trading': 571,
#  'agalawatte plantations': 572,
#  'ally weerasinghe': 573,
#  'almar teas': 574,
#  'almar trading  pte': 575,
#  'alpha apperals': 576,
#  'aqua dynamics': 577,
#  'atg lanka': 578,
#  'avomark international p l': 579,
#  'balaji ventures lanka': 580,
#  'barbara sansoni exp': 581,
#  'basilur tea exp': 582,
#  'bio foods': 583,
#  'bogala graphite lanka': 584,
#  'botanicoir lanka': 585,
#  'brandix textiles': 586,
#  'bratex': 587,
#  'canberg lanka': 588,
#  'carlton garments': 589,
#  'ceylon coir fibre industries  l': 590,
#  'ceylon natural coco': 591,
#  'ceylon oxygen': 592,
#  'ceylon rubber indpvt': 593,
#  'ceylon tea land': 594,
#  'ceyquartz mbi': 595,
#  'cinna hotel management services': 596,
#  'classic garments pte': 597,
#  'cocogreen united kingdom lanka': 598,
#  'cocopel lanka': 599,
#  'colombo quality coir products': 600,
#  'comfort bedding internationala p l': 601,
#  'commercial bank of ceylon': 602,
#  'contrinex ceylon': 603,
#  'cosmic poly plast': 604,
#  'courtaulds clothing dambadeniya': 605,
#  'ctp pre packed exp': 606,
#  'd  g spice exp': 607,
#  'd 2 clothing': 608,
#  'd s l lanka': 609,
#  'd t w international': 610,
#  'dlk spice exp': 611,
#  'de la rue lanka currency  secu p l i p z biyagama malwana': 612,
#  'dimara distributors': 613,
#  'durtek lanka': 614,
#  'e m e engineering lanka': 615,
#  'eam maliban texts mahiyanganaya pl': 616,
#  'ecochem': 617,
#  'enterprising enterprises': 618,
#  'ever green exp': 619,
#  'fairdeal trading': 620,
#  'falcon trading': 621,
#  'finlays colombo': 622,
#  'flex film international': 623,
#  'flintec transducers': 624,
#  'friends poly packagaing': 625,
#  'gp de silva  sons international': 626,
#  'galuku hydroponics': 627,
#  'global clothing international': 628,
#  'grow soil substrates': 629,
#  'growrite substrates': 630,
#  'haifa traders': 631,
#  'hands international intimates  l': 632,
#  'haskel garments': 633,
#  'hayleys free zone': 634,
#  'herbert stephan lanka': 635,
#  'horombawa coir products': 636,
#  'innovative knitwear': 637,
#  'inter tea': 638,
#  'intern pulses processing induspl': 639,
#  'intexmode': 640,
#  'intl precision moulds tools p': 641,
#  'ishana exp': 642,
#  'j m a imp exp lanka': 643,
#  'j a de silva': 644,
#  'jaindi exp': 645,
#  'jay jay mills lanka': 646,
#  'kmk seafoods': 647,
#  'koiralive exp': 648,
#  'l c packaging industries': 649,
#  'lakro enterprises': 650,
#  'lalan eco latex': 651,
#  'lanka coco products': 652,
#  'lanka leather fashion': 653,
#  'lanka shipping logistics': 654,
#  'leoch lanka': 655,
#  'm c enterprises': 656,
#  'macson mesh industries': 657,
#  'manchiee de coco products': 658,
#  'mas active': 659,
#  'meezan ancoombra plantations': 660,
#  'melray international': 661,
#  'msh packaing industries': 662,
#  'mufaddal traders': 663,
#  'multi fish lanka': 664,
#  'multy coco products': 665,
#  'n exp imp': 666,
#  'nasna imp  exp garments industries': 667,
#  'natural collections': 668,
#  'nestle lanka': 669,
#  'new asia traders': 670,
#  'nikini automation systems': 671,
#  'nippon knit': 672,
#  'orava': 673,
#  'orient trading': 674,
#  'pearl lanka kandy': 675,
#  'peoples organi for development imp exp': 676,
#  'piyadasa k k koralge fibre expoters': 677,
#  'plant lipids lanka': 678,
#  'praventure international': 679,
#  'qualitea ceylon': 680,
#  'quality fish exp': 681,
#  'r k s lanka': 682,
#  'rainbow aquarium isuru': 683,
#  'rainbow foods': 684,
#  'rainco industries': 685,
#  'raux brothers': 686,
#  'ravi industries': 687,
#  'rawfood sri lanka galgoda': 688,
#  'regal calibre lk': 689,
#  'regency teas': 690,
#  'reliance diamond tool    south asia g m': 691,
#  'richard pieris natural foams': 692,
#  'rjv international': 693,
#  's and s lanka gloves': 694,
#  's c printing international': 695,
#  'sd chemicals': 696,
#  's n industries': 697,
#  'safex': 698,
#  'sampath associates internl': 699,
#  'samson bikes': 700,
#  'sanjeewa aquatics': 701,
#  'sathuta international': 702,
#  'sds spices': 703,
#  'seijitsu lanka': 704,
#  'serendipol': 705,
#  'shums': 706,
#  'silvermill natural beverages': 707,
#  'sirio': 708,
#  'sirisanda timber products exp': 709,
#  'skyline baseball': 710,
#  'sobi imp exp': 711,
#  'sol trim international': 712,
#  'south asia granite marbel': 713,
#  'south asia textile industries lanka': 714,
#  'southern spars international p': 715,
#  'spedicon logistics': 716,
#  'spice link': 717,
#  'star fashion clothing': 718,
#  'straintec': 719,
#  'stretch line': 720,
#  'summer plants': 721,
#  'sun sauru': 722,
#  'sunray aquatics': 723,
#  't print': 724,
#  'tharanganee garments': 725,
#  'three acre farms': 726,
#  'toyo cushion lanka': 727,
#  'trelleborg lanka': 728,
#  'tropical sea foods exp': 729,
#  'trump coir products': 730,
#  'udara lanka coir exp': 731,
#  'union apperals': 732,
#  'uniworld teas': 733,
#  'variosystems': 734,
#  'wacoal timex': 735,
#  'western paper industries': 736,
#  'wilkins spence packaging lanka pv l': 737,
#  'ykk lanka': 738,
#  'a f jones exporters ceylon': 739,
#  'abhiman apparel': 740,
#  'aes kelanitissa': 741,
#  'agro nutrition': 742,
#  'alloy fabricators international p l': 743,
#  'alpha exp': 744,
#  'anods cocoa': 745,
#  'ansell textiles lanka': 746,
#  'anura wijemanne associates': 747,
#  'arpitalian compact soles': 748,
#  'asian cutting lanka': 749,
#  'aslan conchshells enterprises': 750,
#  'aura solutions': 751,
#  'b p l teas': 752,
#  'b w holding': 753,
#  'beira brush': 754,
#  'black tea exp': 755,
#  'boehm and leckner multimoulds': 756,
#  'bogawantalawa plantation teas': 757,
#  'capitol lanka': 758,
#  'ceylon 2 u foods': 759,
#  'ceylon agro industries': 760,
#  'ceylon biscuits lanka exp   cbl exp': 761,
#  'ceylon biscuits': 762,
#  'ceylon commodity marketing': 763,
#  'ceylon pencil': 764,
#  'ceylon quartz industries': 765,
#  'christina packaging accessories p': 766,
#  'city cycle industries': 767,
#  'clarion logistics': 768,
#  'classic teas': 769,
#  'cocotech exp lanka': 770,
#  'colmans garments industries  l': 771,
#  'colombo stone industries': 772,
#  'colossus': 773,
#  'concord apparel': 774,
#  'consarc': 775,
#  'crystal martin central': 776,
#  'dani foods lanka': 777,
#  'dial textile industries': 778,
#  'dialog axiata': 779,
#  'diamond dreams': 780,
#  'dole lanka': 781,
#  'eastern merchants': 782,
#  'edna cocoa products': 783,
#  'ellawala exp': 784,
#  'elsteel': 785,
#  'embody trading': 786,
#  'eoas organics private limited': 787,
#  'etna trade links': 788,
#  'euro scan exp': 789,
#  'exotic aquarium': 790,
#  'fairmount fashion': 791,
#  'favourite international exp l': 792,
#  'flexi print': 793,
#  'fresh tea exp': 794,
#  'fulgar lanka': 795,
#  'gamma lanka garment industr': 796,
#  'global sports lanka': 797,
#  'gospel house handi crafts': 798,
#  'green farms': 799,
#  'green global imp  exp': 800,
#  'green grow exp': 801,
#  'green scape coir exp': 802,
#  'green view international': 803,
#  'greenstone': 804,
#  'hatton national bank': 805,
#  'hayleys energy services lanka  l': 806,
#  'hddes extracts': 807,
#  'hemas mfg': 808,
#  'heritage teas premium services': 809,
#  'hicom international aquaculture': 810,
#  'hva foods': 811,
#  'i p m t lanka': 812,
#  'intex lanka': 813,
#  'isabella  private': 814,
#  'island exp': 815,
#  'j e p australia': 816,
#  'jawad interanational': 817,
#  'jumeirah lanka': 818,
#  'kik lanka': 819,
#  'kalaro': 820,
#  'kalnara commodities': 821,
#  'kanara exp': 822,
#  'kathiravan imp exp': 823,
#  'keana': 824,
#  'kent display': 825,
#  'kokosfibre exp': 826,
#  'kushuhara trading': 827,
#  'l  s engineering': 828,
#  'lbspices trading': 829,
#  'lak methodic': 830,
#  'lanka brush exp': 831,
#  'lanka canneries': 832,
#  'lanka commodity trading': 833,
#  'lanka maritime services': 834,
#  'lanka pets aquatics': 835,
#  'libra exp': 836,
#  'link natural products': 837,
#  'ltl projects': 838,
#  'lumbini tea exp': 839,
#  'mainettech lanka': 840,
#  'manikto gem': 841,
#  'mapa lalan': 842,
#  'marangoni industrial tyres lanka': 843,
#  'master tea  spices': 844,
#  'mccallum nurseries global': 845,
#  'merandiv': 846,
#  'microcells': 847,
#  'midaya ceramic': 848,
#  'millennium informtn technologies ld': 849,
#  'minra garmnets': 850,
#  'modern printing design lanka': 851,
#  'morex lanka': 852,
#  'n j fishing exp': 853,
#  'n m k agro industries': 854,
#  'naturub lingerie accessories': 855,
#  'new colombo aquarium': 856,
#  'new world gem': 857,
#  'nico battery mfg': 858,
#  'north line asia': 859,
#  'ocean lanka': 860,
#  'of singworld lanka': 861,
#  'of trendywear': 862,
#  'omega green': 863,
#  'orchid collection': 864,
#  'orel corporation': 865,
#  'oxley threads lanka': 866,
#  'p c e lanka': 867,
#  'p a enterpises': 868,
#  'pms traders': 869,
#  'permess international': 870,
#  'plastipak industrial textiles': 871,
#  'plastipak lanka': 872,
#  'presstona tiles lanka': 873,
#  'prestige quality international': 874,
#  'printcare packaging': 875,
#  'printcare secure': 876,
#  'printcare universal': 877,
#  'r j v international': 878,
#  'r p c polymers': 879,
#  'raihaan centre': 880,
#  'rainwear': 881,
#  'rajarata food products': 882,
#  'rakshaa': 883,
#  'randunu fabric': 884,
#  'ranjithaa pulses splitting': 885,
#  'reality management services': 886,
#  'renuka agro exp': 887,
#  'renuka teas ceylon': 888,
#  'rileys': 889,
#  'rinstrum': 890,
#  'roshan exp': 891,
#  'ruhunu imp  exp': 892,
#  'ruky enterprises': 893,
#  's  d associates': 894,
#  's l coco fibre mfg copvt': 895,
#  's st clair teas': 896,
#  's r metals': 897,
#  'sasilva  sons lanka': 898,
#  'sadeepa enterprises': 899,
#  'salike': 900,
#  'samarasinghe brothers': 901,
#  'samson international': 902,
#  'samson rubber products': 903,
#  'sancta maria coir products': 904,
#  'saru international': 905,
#  'scanwell logistics colombo': 906,
#  'screenline': 907,
#  'search lanka travels cons': 908,
#  'seneviratne bandula': 909,
#  'senok aviation': 910,
#  'serenco trading': 911,
#  'shanghai steels': 912,
#  'siddhalepa exp': 913,
#  'snacka lanka': 914,
#  'sri lanka handicrafts board': 915,
#  'stone asia': 916,
#  'superfine teas': 917,
#  't s buttons lanka': 918,
#  'tea  herb': 919,
#  'tea packs': 920,
#  'techstar packaging': 921,
#  'texorn': 922,
#  'the green rubber': 923,
#  'the green rubber toy': 924,
#  'the island watch': 925,
#  'the leaf': 926,
#  'trelleborg wheel systems lanka p l': 927,
#  'triple safety': 928,
#  'tropical abundance': 929,
#  'tropical green': 930,
#  'uk beverages': 931,
#  'united tobacco processing': 932,
#  'united tractor  equipemnt': 933,
#  'usui lanka': 934,
#  'venture hotel supplies': 935,
#  'walters bay bogawantalawa estates': 936,
#  'warna exporters': 937,
#  'wayamba coco peat galaudawattu': 938,
#  'wichy plantation': 939,
#  'winmark international': 940,
#  'woodman lanka': 941,
#  'worldwide commodities': 942,
#  'yus exim': 943,
#  'zigo technology': 944,
#  'as chatoor': 945,
#  'acl cables': 946,
#  'agio tobacco processing': 947,
#  'akai fasteners': 948,
#  'aramco polythene': 949,
#  'arcadian sourcing': 950,
#  'asons': 951,
#  'ayubowan gift collection': 952,
#  'b s h ventures': 953,
#  'beira parawood products': 954,
#  'benham international': 955,
#  'bio extracts': 956,
#  'bismil holdings': 957,
#  'boumy lanka': 958,
#  'brenntag lanka': 959,
#  'carbon activated corporation lanka': 960,
#  'cbl natural foods': 961,
#  'ceramic world': 962,
#  'ceylon chain mfg': 963,
#  'ceylon fresh teaspvt': 964,
#  'ceylon machine twisted fibre': 965,
#  'ceylon recycle industries': 966,
#  'ceylon victorias teas': 967,
#  'chevron lubricants lanka': 968,
#  'cliftex industriesprivate': 969,
#  'coco house': 970,
#  'coir project international lanka': 971,
#  'crystal martin garments': 972,
#  'cwt globelink colombo': 973,
#  'd p l universal gloves': 974,
#  'd2 clothing': 975,
#  'dankotuwa porcelain': 976,
#  'darwish trading': 977,
#  'david pieris motor': 978,
#  'dellogistics   no': 979,
#  'derana international': 980,
#  'dhl global forwarding lanka': 981,
#  'dialog broadband networks': 982,
#  'diamond international lanka': 983,
#  'diesel and motor engineering': 984,
#  'dilshara international': 985,
#  'doctor dona exp importers pl': 986,
#  'dsl global': 987,
#  'dynamic tecnologies': 988,
#  'eco engineers': 989,
#  'eco soil substrates': 990,
#  'eden pharmaceuticals': 991,
#  'embilmeegama tea': 992,
#  'energy generators': 993,
#  'eu retec': 994,
#  'euro substrates': 995,
#  'everest industrial lanka': 996,
#  'expack corrugated cartons': 997,
#  'ezzy sails lanka': 998,
#  'fantasia elastics': 999,
#  'fgm lanka': 1000,
#  ...}

# %%
# add new firm_id column to the dataframe
comm_trans_df['firm_id'] = comm_trans_df['firm_name_clean'].map(maps)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
comm_trans_df
# Out:
#                                    firm_name  ...  firm_id
# 0                 A Class Trading Pvt., Ltd.  ...        1
# 1                     A K Y Lanka Pvt., Ltd.  ...        2
# 2       A R Freight Care Services Pvt., Ltd.  ...        3
# 3       Ace International Express Pvt., Ltd.  ...        4
# 4                   Aero Dynamics (Pvt) Ltd.  ...        5
# ...                                      ...  ...      ...
# 106521                 Usui Lanka (Pvt) Ltd.  ...      934
# 106522               Variosystems Pvt., Ltd.  ...      734
# 106523                  Wayamba Natural Peat  ...     2281
# 106524       Wichy Plantation Co. (Pvt) Ltd.  ...      939
# 106525             Workwear Lanka (Pvt) Ltd.  ...      567
#
# [105890 rows x 4 columns]

# %%
#Top 10 companies by number of transactions

top_10 = comm_trans_df['firm_name_clean'].value_counts()[:10]
#plot for the top 10 countries
plt.figure(figsize=(12,6))
plt.xticks(rotation=70)
plt.title("10 most active firms")
sns.barplot(x=top_10.index, y=top_10, palette = 'Spectral')
